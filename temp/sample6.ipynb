# %%
import pandas as pd
df = pd.read_csv('../doit_pandas/data/gapminder.tsv', sep = '\t')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
# country      1704 non-null object
# continent    1704 non-null object
# year         1704 non-null int64
# lifeExp      1704 non-null float64
# pop          1704 non-null int64
# gdpPercap    1704 non-null float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df_groupby = df.groupby('year')
type(df_groupby)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
df_groupby

# %%
# df_groupby.info()    # XX
df_groupby['country']  # OK

# %%
df_groupby['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
type(df_groupby['lifeExp'].mean())
# Out:
# pandas.core.series.Series

# %%
df_groupby = df.groupby(['year','country'])
df_groupby['lifeExp'].mean()
# Out:
# year  country
# 1952  Afghanistan           28.801
#       Albania               55.230
#       Algeria               43.077
#       Angola                30.015
#       Argentina             62.485
#                              ...
# 2007  Vietnam               74.249
#       West Bank and Gaza    73.422
#       Yemen, Rep.           62.698
#       Zambia                42.384
#       Zimbabwe              43.487
# Name: lifeExp, Length: 1704, dtype: float64

# %%
df_groupby = df.groupby(['year','continent','country'])
df_groupby['lifeExp'].mean()
# Out:
# year  continent  country
# 1952  Africa     Algeria           43.077
#                  Angola            30.015
#                  Benin             38.223
#                  Botswana          47.622
#                  Burkina Faso      31.975
#                                     ...
# 2007  Europe     Switzerland       81.701
#                  Turkey            71.777
#                  United Kingdom    79.425
#       Oceania    Australia         81.235
#                  New Zealand       80.204
# Name: lifeExp, Length: 1704, dtype: float64

# %%
df_groupby = df.groupby(['year','continent'])
df_groupby['gdpPercap'].mean()
# Out:
# year  continent
# 1952  Africa        1252.572466
#       Americas      4079.062552
#       Asia          5195.484004
#       Europe        5661.057435
#       Oceania      10298.085650
# 1957  Africa        1385.236062
#       Americas      4616.043733
#       Asia          5787.732940
#       Europe        6963.012816
#       Oceania      11598.522455
# 1962  Africa        1598.078825
#       Americas      4901.541870
#       Asia          5729.369625
#       Europe        8365.486814
#       Oceania      12696.452430
# 1967  Africa        2050.363801
#       Americas      5668.253496
#       Asia          5971.173374
#       Europe       10143.823757
#       Oceania      14495.021790
# 1972  Africa        2339.615674
#       Americas      6491.334139
#       Asia          8187.468699
#       Europe       12479.575246
#       Oceania      16417.333380
# 1977  Africa        2585.938508
#       Americas      7352.007126
#       Asia          7791.314020
# ...

# %%
groupby_mean = df_groupby['gdpPercap'].mean()
type(groupby_mean)
# Out:
# pandas.core.series.Series

# %%
groupby_mean = df_groupby['gdpPercap','pop','lifeExp'].mean()
groupby_mean
# Out:
#                    gdpPercap           pop    lifeExp
# year continent
# 1952 Africa      1252.572466  4.570010e+06  39.135500
#      Americas    4079.062552  1.380610e+07  53.279840
#      Asia        5195.484004  4.228356e+07  46.314394
#      Europe      5661.057435  1.393736e+07  64.408500
#      Oceania    10298.085650  5.343003e+06  69.255000
# 1957 Africa      1385.236062  5.093033e+06  41.266346
#      Americas    4616.043733  1.547816e+07  55.960280
#      Asia        5787.732940  4.735699e+07  49.318544
#      Europe      6963.012816  1.459635e+07  66.703067
#      Oceania    11598.522455  5.970988e+06  70.295000
# 1962 Africa      1598.078825  5.702247e+06  43.319442
#      Americas    4901.541870  1.733081e+07  58.398760
#      Asia        5729.369625  5.140476e+07  51.563223
#      Europe      8365.486814  1.534517e+07  68.539233
#      Oceania    12696.452430  6.641759e+06  71.085000
# 1967 Africa      2050.363801  6.447875e+06  45.334538
# ...

# %%
df_groupby['pop'].sum()
# Out:
# year  continent
# 1952  Africa        237640501
#       Americas      345152446
#       Asia         1395357351
#       Europe        418120846
#       Oceania        10686006
# 1957  Africa        264837738
#       Americas      386953916
#       Asia         1562780599
#       Europe        437890351
#       Oceania        11941976
# 1962  Africa        296516865
#       Americas      433270254
#       Asia         1696357182
#       Europe        460355155
#       Oceania        13283518
# 1967  Africa        335289489
#       Americas      480746623
#       Asia         1905662900
#       Europe        481178958
#       Oceania        14600414
# 1972  Africa        379879541
#       Americas      529384210
#       Asia         2150972248
#       Europe        500635059
#       Oceania        16106100
# 1977  Africa        433061021
#       Americas      578067699
#       Asia         2384513556
#       Europe        517164531
#       Oceania        17239000
# ...
