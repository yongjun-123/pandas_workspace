# %%
import pandas as pd
df = pd.read_csv('~/Documents/pandas_workspace/doit_pandas/data/gapminder.tsv', sep = '\t')

# %%
import matplotlib as plt

# %%
df_af = df[df['country']=='Afghanistan']

# %%
df_af_gr = df_af.groupby(['year'])

# %%
a = df_af_gr['pop'].sum()

# %%
a.plot(x='year')

# %%
a.plot()

plt.pyplot.grid(True)
